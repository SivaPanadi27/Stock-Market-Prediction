# %% [markdown]
# #Stock Prediction Using Supervised Machine Learning
# Nov-14[Day-1]:Enivronment Setup + Importing libiraries + Stock Selection + Data testing

# %%
#Environment Setup
# !pip install yfinance pandas_ta --quiet

'''yfinance : Python library to download stock market OHLC data + fundamentals
  pandas_ta: Used later for generating technical indicators like RSI, MACD,etc...'''
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 46.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 13.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# ...

# %%
#Importing Libraries
import yfinance as yf
import pandas as pd
import numpy as np

# %% [markdown]
# **Pandas**:
#
# *   A Python library used to handle and analyze structured data in      table      format (data frames)
#
#
# *  It is used  to easily load, clean, inspect, and manipulate stock datasets.
# *  In this project we use it to read CSV files, clean OHLC data, merge datasets, and prepare features for machine learning.
# ---
# **Numpy:**
#
#
# *   A numerical computing library used for fast mathematical operations on arrays.
# *  It is used to perform quick calculations needed for indicators, returns, and numerical ML features.
#
#
# *   Used behind the scenes when calculating technical indicators and transforming data for ML.
# ---
# **yfinance:**
#
#
# *   An API that downloads stock market data (prices + fundamentals) from Yahoo Finance.
# *   To automatically fetch historical OHLC data and company fundamental ratios for our selected stocks.
#
#
# * It is used  to download technical data (OHLCV) and fundamental financial data for all 10 stocks.

# %%
#List of 10 Selected stocks
stocks = ["RELIANCE.NS","TCS.NS","INFY.NS","HDFCBANK.NS","ICICIBANK.NS","ITC.NS", "SBIN.NS","HINDUNILVR.NS",
          "BHARTIARTL.NS","LT.NS"]
stocks
# Out:
# ['RELIANCE.NS',
#  'TCS.NS',
#  'INFY.NS',
#  'HDFCBANK.NS',
#  'ICICIBANK.NS',
#  'ITC.NS',
#  'SBIN.NS',
#  'HINDUNILVR.NS',
#  'BHARTIARTL.NS',
#  'LT.NS']

# %%
#Data Testing
test_data = yf.download("RELIANCE.NS", start="2020-01-01", end="2024-01-01")
test_data.head()
test_data.to_csv("RELIANCE_test.csv")
# Out:
# /tmp/ipython-input-3667440595.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   test_data = yf.download("RELIANCE.NS", start="2020-01-01", end="2024-01-01")
# [*********************100%***********************]  1 of 1 completed
